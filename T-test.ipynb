# %% [markdown]
# ## **One Sample T-test**

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import math
np.random.seed(6)
school_age=stats.poisson.rvs(loc=18,mu=35,size=1500) #loc is most left value, mean=35
classA_age=stats.poisson.rvs(loc=18,mu=30,size=60)

# %%
classA_age.mean()
# Out:
# np.float64(46.9)

# %%
school_age.mean()
# Out:
# np.float64(53.303333333333335)

# %%
_,_p_value=stats.ttest_1samp(a=classA_age,popmean=school_age.mean())

# %%
_p_value
# Out:
# np.float64(1.139027071016194e-13)

# %%
if _p_value<0.05:
  print("We are rejecting null hypothesis")
else:
  print("We are accepting null hypothesis")
# Out:
# We are rejecting null hypothesis

# %% [markdown]
# ## **Two Sample T-test**

# %%
np.random.seed(12)
classB_age=stats.poisson.rvs(loc=18,mu=33,size=60)
classB_age.mean()
# Out:
# np.float64(50.63333333333333)

# %%
_,_p_value=stats.ttest_ind(a=classA_age,b=classB_age,equal_var=False)

# %%
if _p_value<0.05:
  print("We are rejecting null hypothesis")
else:
  print("We are accepting null hypothesis")
# Out:
# We are rejecting null hypothesis

# %%
weight1=[40, 70, 10, 90, 120, 30, 80, 50, 10, 60, 20, 110, 14, 13, 10]
weight2=weight1+stats.norm.rvs(scale=5,loc=-1.25,size=15)

# %%
print(weight1)
print(weight2)
# Out:
# [40, 70, 10, 90, 120, 30, 80, 50, 10, 60, 20, 110, 14, 13, 10]
# [ 45.57926457  74.91022437  11.00444617  85.54295091 111.86201983
#   33.57873174  72.3299827   42.3771395   16.36420881  66.05941216
#   18.93827982 107.519014     9.42851213  13.50667769   6.32984284]

# %%
weight_df=pd.DataFrame({"weight_10":np.array(weight1),
                         "weight_20":np.array(weight2),
                         "weight_change":np.array(weight2)-np.array(weight1)})

# %%
weight_df
# Out:
#     weight_10   weight_20  weight_change
# 0          40   45.579265       5.579265
# 1          70   74.910224       4.910224
# 2          10   11.004446       1.004446
# 3          90   85.542951      -4.457049
# 4         120  111.862020      -8.137980
# 5          30   33.578732       3.578732
# 6          80   72.329983      -7.670017
# 7          50   42.377139      -7.622861
# 8          10   16.364209       6.364209
# 9          60   66.059412       6.059412
# 10         20   18.938280      -1.061720
# 11        110  107.519014      -2.480986
# 12         14    9.428512      -4.571488
# 13         13   13.506678       0.506678
# 14         10    6.329843      -3.670157

# %%
_,_p_value=stats.ttest_rel(a=weight1,b=weight2)

# %%
print(_p_value)
# Out:
# 0.5732936534411279

# %%
if _p_value<0.05:
  print("We are rejecting null hypothesis")
else:
  print("We are accepting null hypothesis")
# Out:
# We are accepting null hypothesis
